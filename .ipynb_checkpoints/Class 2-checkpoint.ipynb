# %%
#This is an example of a stack using built in data structures 

class Stack:
    def __init__(self):
        self.items = []
        
    def push(self, item):
        self.items.append(item)
    
    def pop(self) :
           return self.items.pop()
        
    # helper methods    
    def is_empty(self):
        return self.items == []
    
    def size(self):
        return len(self.items)
    
    
    def peek(self):
        return self.items[len(self.items)-1]

# %% [markdown]
# # Problem 2: Invert a string
#
# ## Stacks naturally allow us to invert a sequence of elements if we sequentially push them onto our stack and sequentially pop them from out stack.
#
# Use our stack class above to invert a string such that:
#
#
# reverse("Rafael") returns "leafaR"
# reverse("racecar") returns "racecar"
# reverse("AbCdE") returns "EdCbA"

# %%
def reverse(mystring):
    stack = Stack()
    out = ""
    for letter in mystring:
        stack.push(letter)
    while stack.is_empty() != True:    
        out = out + stack.pop()
    return out
print(reverse("Daniel"))
print(reverse("racecar"))
print(reverse("AbCdE"))  
print(reverse("I am home"))
# Out:
# leinaD
# racecar
# EdCbA
# emoh ma I

# %%
class queue:
    def __init__(self):
        self.items = []
    
    def enqueue(self,item):
        self.items.insert(0,item)
        
    def dequeue(self):
        return self.item.pop()
    
    def is_empty(self):
        return self.items ==[]
        
    def size(self):
        return len(self.items)

# %%
from random import randint
from time import sleep


def square_queue(elements):
    queue = Queue ()
    out = ""
    for element in elements:
        print("Adding %s to our queue." % element)
        queue.enqueue(element)
    while not queue.is_empty():
        datum = queue.dequeue()
        sleep(randint(1,3))
    print("%s squared is %s" % (daum,datum**2))

# %%
square_queue([1, 2, 3, 4, 5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 square_queue([1, 2, 3, 4, 5])
#
# Input In [33], in square_queue(elements)
#       5 def square_queue(elements):
# ----> 6     queue = Queue()
#       7     for element in elements:
#       8         print("Adding %s to our queue." % element)
#
# NameError: name 'Queue' is not defined

# %%
class Node:
    def __init__(self, data):
        self.data= data
        self.above= None

# %%
class Stack:
    def __init__(self):
        self.base = None
        
    def push(self, item):
        if not self.base:
            self.base = Node(item)
        else:
            current = self.base
            while current.above:
                current = current.above
            current.above = Node(item)    
        
    def pop(self):
        pass
    
    def is_empty(self):
        if not self.base:
            return True
        return False
    
    def size(self):
        pass
    
    def peek(self):
        pass
